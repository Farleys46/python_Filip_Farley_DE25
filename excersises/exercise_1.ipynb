# %%
# 0 
import math

sideA = 3
sideB = 4

hypothenuse = sideA ** 2 + sideB ** 2

answer = math.sqrt(hypothenuse)

print(answer)
# Out:
# 5.0

# %%
#1 & 2

results = 300/365

TP = 2
TN = 985
FP = 2
FN = 11

accuracy = (TP + TN)/(TP + TN + FP + FN)

print(accuracy)
# Out:
# 0.987

# %%
# 3 

file_name = "orders_data.csv"

file_size = 3.14

last_modified = 2024

print("=== File metadata ===")
print("Filename:",file_name)
print("Size (MB):",file_size)
print("Last Modified Year:",last_modified)
# Out:
# === File metadata ===
# Filename: orders_data.csv
# Size (MB): 3.14
# Last Modified Year: 2024

# %%
#4

screen_size_inches = int(input("What is your screen size in inches?: "))

screen_size_cm = screen_size_inches * 2.54

print("Your screen size in cm is:",screen_size_cm)
# Out:
# Your screen size in cm is: 33.02

# %%
# 5 Inte avklarad

any_text = input("Enter any text here: ")

x = len(any_text)

print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       1 # 5
#       3 any_text = input("Enter any text here: ")
# ----> 5 x = len(str(any_text))
#       7 print(x)
#
# TypeError: 'str' object is not callable

# %%
radius = 5 
PI = 3.1415 
cool_subject = 'math' 
is_cool = True 
numbers = [1, 2, 41, 2] 

a = type(radius)
b = type(PI)
c = type(cool_subject)
d = type(is_cool)
e = type(numbers)

print(a, b, c, d, e)
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'> <class 'list'>
