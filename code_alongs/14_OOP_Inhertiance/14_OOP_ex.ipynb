# %% [markdown]
# ###Exercises 6

# %%
from numbers import Number
from utils import validate_positive_number
    

class UnitConverter:
    def __init__(self, value: Number):
        self.value = value
        
    @property
    def value(self):
        return self._value
    
    @value.setter
    def value(self, new_value):
        validate_positive_number(new_value)
        
        self._value = new_value
    
    def inch_to_cm(self):
        return 2.54 * self.value
    
    def foot_to_meters(self):
        return 0.3048 * self.value
        
unit_converter = UnitConverter(5)

print(f"{unit_converter.value = }")

try:
    unit_converter.value = "5"
except TypeError as err:
    print(err)
    

try:
    unit_converter.value = -5
except ValueError as err:
    print(err)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 2
#       1 from numbers import Number
# ----> 2 from utils import validate_positive_number
#       5 class UnitConverter:
#       6     def __init__(self, value: Number):
#
# ImportError: cannot import name 'validate_positive_number' from 'utils' (c:\Users\filip\OneDrive\Desktop\DE25\python_Filip_Farley_DE25\code_alongs\14_OOP_Inhertiance\utils.py)
