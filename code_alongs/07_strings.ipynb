# %%
full_name = "Kokchun Giang"

print(f"The last five letters are {full_name[-1:-6:-1]}")
# Out:
# The last five letters are gnaiG

# %%
first_name = "DaViD"
last_name = "jOhANSon"

full_name = first_name.capitalize() + " " + last_name.capitalize()

print(full_name)
# Out:
# David Johanson

# %%
x = "apple,banana,cherry"

x_list = x.split(",")
print(x_list)

joined = " ".join(x_list)
print(joined)
# Out:
# ['apple', 'banana', 'cherry']
# apple banana cherry

# %%
x = "hello_world.pi"

if x.startswith("hello") and x.endswith(".py"):
    print("It starts with hello and ends with .py")
else:
    print("False")
# Out:
# False

# %%
x = "Python"

reverse = x[::-1]

print(reverse)
# Out:
# nohtyP

# %%
x = "racecar"

if x == x[::-1]:
    print("True")
else:
    print("False")
# Out:
# True

# %%
import re 
text = "Det var en gång en katt som tog på sig en hatt."

list_letter_att = re.findall(".att", text)

print(list_letter_att)
# Out:
# ['katt', 'hatt']

# %%
import re

personal_number = "Ida: 19650504-1234, Berit: 980221-4321"

personal_number_eight = re.findall(r"\d{8}", personal_number)

print(personal_number_eight)
# Out:
# ['19650504']

# %%
x = "Hello World"

result = re.sub(r"[aiouyeAOIUYE]", "", x)

print(result)
# Out:
# Hll Wrld
