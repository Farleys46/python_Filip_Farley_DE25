# %% [markdown]
# ###Polymorphism
#
# "many shapes"
#
# - same function name or operator used for different types
# - e.g. "2" + "3" -> "23"
# - -2 + 3 -> 5
# "In this example it has been operator overloaded

# %%
"2" + "22"
# Out:
# '222'

# %%
2 + "2"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 2 + "2"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
[2] + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 [2] + 2
#
# TypeError: can only concatenate list (not "int") to list

# %%
[2]*6
# Out:
# [2, 2, 2, 2, 2, 2]

# %% [markdown]
# ### Polymorphism in class methods

# %%
class Fish:
    def __init__(self, name):
        self.name = name
        
    def __str__(self):
        return (f"I am a fish, my name is {self.name}")

    def speak(slef):
        print(f"Fish {self.name} says blupp blupp")

class Fox:
    def __init__(self, name):
        self.name = name
        
    def __str__(self):
        return (f"I am a fox, my name is {self.name}, no one knows how i sound")
    
    def speak(self):
        return NotImplemented
    
animals = [Fish("Fisky"), Fish("Goldylock"), Fox("Ylvis")]

for animal in animals:
    print(animal)
    animal.speak()
# Out:
# I am a fish, my name is Fisky
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 25
#      23 for animal in animals:
#      24     print(animal)
# ---> 25     animal.speak()
#
# Cell In[5], line 9, in Fish.speak(slef)
#       8 def speak(slef):
# ----> 9     print(f"Fish {self.name} says blupp blupp")
#
# NameError: name 'self' is not defined

# %%
<div style="max-width:66ch;">

## Operator overloading

<table style="display:inline-block; text-align:left;">
  <tr style="background-color: #174A7E; color: white;">
    <th>Operator</th>
    <th>Dunder Method</th>
  </tr>
  <tr>
    <td style="text-align: center;">+</td>
    <td style="text-align: center;">__add__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">-</td>
    <td style="text-align: center;">__sub__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">*</td>
    <td style="text-align: center;">__mul__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">/</td>
    <td style="text-align: center;">__div__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">//</td>
    <td style="text-align: center;">__floordiv__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">%</td>
    <td style="text-align: center;">__mod__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">**</td>
    <td style="text-align: center;">__pow__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;"><</td>
    <td style="text-align: center;">__lt__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;"><=</td>
    <td style="text-align: center;">__le__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">></td>
    <td style="text-align: center;">__gt__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">>=</td>
    <td style="text-align: center;">__ge__(self, other)</td>
  </tr>
  <tr>
    <td style="text-align: center;">==</td>
    <td style="text-align: center;">__eq__(self, other)</td>
  </tr>
</table>

</div>
# Out:
#   Cell In[7], line 1
#     <div style="max-width:66ch;">
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Vector

# %%
from utils import validate_number
from numbers import Number

class Vector:
    """A class representing a euclidean vector"""
    def __init__(self, *numbers):
        print(type(numbers))
        print(numbers)
        
        for number in numbers:
            validate_number(number)
            
        if len(numbers) <= 0:
            raise ValueError("Vector cant be empty")
        
        self._numbers = numbers
        
    @property
    def numbers(self):
        return self.numbers
        
        
v1 = Vector(1, 2)
try:
    v2 = Vector("1", 2)
except TypeError as err:
    print(err)
    
try:
    v2 = Vector()
except ValueError as err:
    print(err)
# Out:
# <class 'tuple'>
# (1, 2)
# <class 'tuple'>
# ('1', 2)
# elements must be numbers not <class 'str'>
# <class 'tuple'>
# ()
# Vector cant be empty

# %%
class Vector:
    """A class representing a euclidean vector"""
    def __init__(self, *numbers):
        print(type(numbers))
        print(numbers)
        
        for number in numbers:
            validate_number(number)
            
        if len(numbers) <= 0:
            raise ValueError("Vector cant be empty")
        
        self._numbers = numbers
        
    @property
    def numbers(self):
        return self.numbers
    
v3 = Vector(1, 1)

v3.numbers
# Out:
# <class 'tuple'>
# (1, 1)
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[2], line 21
#      17         return self.numbers
#      19 v3 = Vector(1, 1)
# ---> 21 v3.numbers
#
# Cell In[2], line 17, in Vector.numbers(self)
#      15 @property
#      16 def numbers(self):
# ---> 17     return self.numbers
#
# Cell In[2], line 17, in Vector.numbers(self)
#      15 @property
#      16 def numbers(self):
# ---> 17     return self.numbers
#
#     [... skipping similar frames: Vector.numbers at line 17 (2974 times)]
#
# Cell In[2], line 17, in Vector.numbers(self)
#      15 @property
#      16 def numbers(self):
# ---> 17     return self.numbers
#
# RecursionError: maximum recursion depth exceeded
