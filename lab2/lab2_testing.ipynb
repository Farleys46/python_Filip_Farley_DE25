# %% [markdown]
# ### Strukturera all testing

# %%
from shape import Shape
from circle import Circle
from rectangle import Rectangle
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\filip\OneDrive\Desktop\DE25\python_Filip_Farley_DE25\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 2
#     from circle import Circle
#
#   File c:\Users\filip\OneDrive\Desktop\DE25\python_Filip_Farley_DE25\lab2\circle.py:15
#     if not isinstance(radius, Number) (radius)):
#                                               ^
# SyntaxError: unmatched ')'

# %% [markdown]
# Test Shapes:

# %%
circle1 = Circle(2, 5, 2)
circle2 = Circle(2, 2, 5)
circle3 = Circle(0, 0, 1)
rectangle1 = Rectangle(3, 3, 3, 4)
rectangle2 = Rectangle(2, 4, 7, 3)
rectangle3 = Rectangle(0, 0, 5, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 circle1 = Circle(2, 5, 2)
#       2 circle2 = Circle(2, 2, 5)
#       3 circle3 = Circle(0, 0, 1)
#
# NameError: name 'Circle' is not defined

# %% [markdown]
# ### Area Testing:

# %%
print(circle1.area)
print(circle2.area)
print(circle3.area)
print(rectangle1.area)
print(rectangle2.area)
print(rectangle3.area)
# Out:
# 12.56636
# 78.53975
# 3.14159
# 12
# 21
# 25

# %% [markdown]
# ### Perimeter testing

# %%
print(circle1.perimeter)
print(circle2.perimeter)
print(circle3.perimeter)
print(rectangle1.perimeter)
print(rectangle2.perimeter)
print(rectangle3.perimeter)
# Out:
# 12.56636
# 31.4159
# 6.28318
# 14
# 20
# 20

# %% [markdown]
# ### Is unit circle

# %%
circle2.is_unit_circle()
# Out:
# False

# %%
circle3.is_unit_circle()
# Out:
# True

# %% [markdown]
# ### Is Square

# %%
rectangle1.is_square()
# Out:
# False

# %%
rectangle3.is_square()
# Out:
# True

# %% [markdown]
# ### Translate Testing

# %%
# Test shapes:
circle5 = Circle(1, 3, 4.5)
rectangle5 = Rectangle(4, 4, 3, 6)

# Print first positions
print("Before")
print(circle5)
print(rectangle5)

# Use translate method
circle5.translate(-2, -3)
rectangle5.translate(-2, -2)


print("\nAfter translate:")
print(circle1)
print(rectangle1)

circle5.plot()
rectangle5.plot()
# Out:
# Before
# The Circle has the values X = 1, Y = 3
# The Rectangle has the values X = 4, Y = 4
#
# After translate:
# The Circle has the values X = 2, Y = 5
# The Rectangle has the values X = 3, Y = 3

# %% [markdown]
# ### Comparison Operators

# %%
circle1.__eq__(circle2)
# Out:
# False

# %%
rectangle1.__lt__(circle2)
# Out:
# True

# %%
circle1.__gt__(rectangle2)
# Out:
# False

# %%
rectangle1.__le__(circle1)
# Out:
# True

# %%
rectangle2.__ge__(rectangle1)
# Out:
# True

# %% [markdown]
# ### __str__ overload

# %%
circle1.__str__()
# Out:
# 'The Circle has the values X = 2, Y = 5'

# %% [markdown]
# ### __repr__ overload

# %%
rectangle1.__repr__()
# Out:
# "<class 'rectangle.Rectangle'>x:3, y:3"

# %% [markdown]
# ### Plotting test

# %%
for shape in [rectangle1, rectangle2, circle1, circle2]:
    shape.plot()

# %% [markdown]
# ### Error Handling

# %% [markdown]
# #### Class Shape Error Handling

# %%
circle4 = Circle(2, 2, "three")

circle4.area
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 circle4 = Circle(2, 2, "three")
#       3 circle4.area
#
# File c:\Users\filip\OneDrive\Desktop\DE25\python_Filip_Farley_DE25\lab2\circle.py:14, in Circle.__init__(self, x, y, radius)
#      12 #ErrorHandling.
#      13 if not all(isinstance(value, Number) for value in (x, y, radius )):
# ---> 14     raise TypeError(f"values must be of type int or float")
#      15 if radius <= 0:
#      16     raise ValueError(f"Radius must be positive and not {radius}")
#
# TypeError: values must be of type int or float

# %% [markdown]
# #### Class Circle error handling

# %%
circle6 = Circle(1, 1, "3")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 circle6 = Circle(1, 1, "3")
#
# NameError: name 'Circle' is not defined
