# %%
from shape import Shape
from circle import Circle
from rectangle import Rectangle

circle1 = Circle(2, 5, 2)

print(circle1.area)
# Out:
# 12.56636

# %%
circle2 = Circle(2, 2, 5)
rectangle1 = Rectangle(3, 3, 3, 4)
print(circle2.area)
# Out:
# 78.53975

# %%
circle2.__gt__(circle1)
#print(rectangle1.area)
# Out:
# True

# %%
rectangle1.__le__(circle2)
# Out:
# True

# %%
circle1.plot()

# %%
rectangle1.plot()

# %%
circle1.__str__()
# Out:
# 'The Circle has the values X = 2, y = 5'

# %%
rectangle1.__repr__()
# Out:
# 'x:3, y:3'

# %%
rectangle1.plot_rect()

# %%
rectangle1.translate(0, 2)
rectangle1.plot_rect()

# %%
for shape in [rectangle1, circle1, circle2]:
    shape.plot()

# %%
# Create shapes
circle1 = Circle(2, 3, 4)
rectangle1 = Rectangle(0, 0, 2, 5)

# Print first positions
print("Before")
print(circle1)
print(rectangle1)

# Use translate method
circle1.translate(3, 2)
rectangle1.translate(-2, 5)


print("\nAfter translate:")
print(circle1)
print(rectangle1)

circle1.plot()
rectangle1.plot()
# Out:
# Before
# The Circle has the values X = 2, y = 3
# The Rectangle has the values X = 0, y = 0
#
# After translate:
# The Circle has the values X = 5, y = 5
# The Rectangle has the values X = -2, y = 5
